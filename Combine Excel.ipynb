# %% [markdown]
# ## **Catatan**
# Banyak merk yang kaya Solo gitu kaya Maxus yang cuman jual mobil listrik

# %%
import pandas as pd

# %%
df1 = pd.read_excel('E:/Important/Machine-Learning/Dataset/Mobil Indonesia/Audi.xlsx')
df2 = pd.read_excel('E:/Important/Machine-Learning/Dataset/Mobil Indonesia/BMW.xlsx')
df3 = pd.read_excel('E:/Important/Machine-Learning/Dataset/Mobil Indonesia/Chery.xlsx')
df4 = pd.read_excel('E:/Important/Machine-Learning/Dataset/Mobil Indonesia/Citroen.xlsx')
df5 = pd.read_excel('E:/Important/Machine-Learning/Dataset/Mobil Indonesia/Daihatsu.xlsx')
df6 = pd.read_excel('E:/Important/Machine-Learning/Dataset/Mobil Indonesia/DFSK.xlsx')
df7 = pd.read_excel('E:/Important/Machine-Learning/Dataset/Mobil Indonesia/Ford.xlsx')
df8 = pd.read_excel('E:/Important/Machine-Learning/Dataset/Mobil Indonesia/Honda.xlsx')
df9 = pd.read_excel('E:/Important/Machine-Learning/Dataset/Mobil Indonesia/Hyundai.xlsx')
df10 = pd.read_excel('E:/Important/Machine-Learning/Dataset/Mobil Indonesia/Isuzu.xlsx')
df11 = pd.read_excel('E:/Important/Machine-Learning/Dataset/Mobil Indonesia/Jaguar.xlsx')
df12 = pd.read_excel('E:/Important/Machine-Learning/Dataset/Mobil Indonesia/Jeep.xlsx')
df13 = pd.read_excel('E:/Important/Machine-Learning/Dataset/Mobil Indonesia/KIA.xlsx')
df14 = pd.read_excel('E:/Important/Machine-Learning/Dataset/Mobil Indonesia/Lexus.xlsx')
df15 = pd.read_excel('E:/Important/Machine-Learning/Dataset/Mobil Indonesia/Mahindra.xlsx')
df16 = pd.read_excel('E:/Important/Machine-Learning/Dataset/Mobil Indonesia/Maxus.xlsx')
df17 = pd.read_excel('E:/Important/Machine-Learning/Dataset/Mobil Indonesia/Mazda.xlsx')
df18 = pd.read_excel('E:/Important/Machine-Learning/Dataset/Mobil Indonesia/Mercedes-Benz.xlsx')
df19 = pd.read_excel('E:/Important/Machine-Learning/Dataset/Mobil Indonesia/MG.xlsx')
df20 = pd.read_excel('E:/Important/Machine-Learning/Dataset/Mobil Indonesia/Mini.xlsx')
df21 = pd.read_excel('E:/Important/Machine-Learning/Dataset/Mobil Indonesia/Mitsubishi.xlsx')
df22 = pd.read_excel('E:/Important/Machine-Learning/Dataset/Mobil Indonesia/Neta.xlsx')
df23 = pd.read_excel('E:/Important/Machine-Learning/Dataset/Mobil Indonesia/Nissan.xlsx')
df24 = pd.read_excel('E:/Important/Machine-Learning/Dataset/Mobil Indonesia/Peugeot.xlsx')
df25 = pd.read_excel('E:/Important/Machine-Learning/Dataset/Mobil Indonesia/Renault.xlsx')
df26 = pd.read_excel('E:/Important/Machine-Learning/Dataset/Mobil Indonesia/Subaru.xlsx')
df27 = pd.read_excel('E:/Important/Machine-Learning/Dataset/Mobil Indonesia/Suzuki.xlsx')
df28 = pd.read_excel('E:/Important/Machine-Learning/Dataset/Mobil Indonesia/Tata.xlsx')
df29 = pd.read_excel('E:/Important/Machine-Learning/Dataset/Mobil Indonesia/Toyota.xlsx')
df30 = pd.read_excel('E:/Important/Machine-Learning/Dataset/Mobil Indonesia/Volkswagen.xlsx')
df31 = pd.read_excel('E:/Important/Machine-Learning/Dataset/Mobil Indonesia/Volvo.xlsx')
df32 = pd.read_excel('E:/Important/Machine-Learning/Dataset/Mobil Indonesia/Wuling.xlsx')

# %%
dfs = [df1, df2, df3, df4, df5, df6, df7, df8, df9, df10,
       df11, df12, df13, df14, df15, df16, df17, df18, df19, df20,
       df21, df22, df23, df24, df25, df26, df27, df28, df29, df30,
       df31, df32]

# %%
combined_df = pd.concat(dfs, ignore_index=True)
combined_df.to_excel('E:/Important/Machine-Learning/Dataset/Mobil Indonesia.xlsx', index=False)
combined_df.to_csv('E:/Important/Machine-Learning/Dataset/Mobil Indonesia.csv', index=False)

# %%
df33 = pd.read_csv('E:/Important/Machine-Learning/Dataset/Mobil Indonesia.csv')

# %%
df33
# Out:
#       Maker                      Model Number of Cylinders  \
# 0      Audi                         A3                 4.0
# 1      Audi                  A3 Hybrid                 4.0
# 2      Audi                         A4                 4.0
# 3      Audi                  A4 Hybrid                 4.0
# 4      Audi                         A5                 4.0
# ..      ...                        ...                 ...
# 260  Wuling                     Cortez                 4.0
# 261  Wuling         Hong Guang MINI EV                 NaN
# 262  Wuling  Hong Guang MINI EV Cabrio                 NaN
# 263  Wuling                    Macaron                 4.0
# 264  Wuling                    Gameboy                 4.0
#
#                                 Engine Type Engine Horse Power  \
# 0    Turbocharged Gasoline Direct Injection                224
# 1    Turbocharged Gasoline Direct Injection                224
# 2    Turbocharged Gasoline Direct Injection                258
# ...

# %%
df33.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 265 entries, 0 to 264
# Data columns (total 14 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Maker                          265 non-null    object
#  1   Model                          265 non-null    object
#  2   Number of Cylinders            206 non-null    object
#  3   Engine Type                    265 non-null    object
#  4   Engine Horse Power             262 non-null    object
#  5   Engine Horse Power RPM         205 non-null    object
#  6   Transmission                   262 non-null    object
#  7   Mixed Fuel Consumption per Km  216 non-null    object
#  8   Fuel Tank Capacity             262 non-null    object
#  9   Acceleration 0 to 100 Km       262 non-null    object
#  10  Max Speed Km per Hour          262 non-null    object
#  11  Fuel Grade (in Octane)         206 non-null    object
# ...
